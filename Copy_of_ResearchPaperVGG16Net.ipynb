# %% [markdown]
# <a href="https://colab.research.google.com/github/m-aliabbas/Pneumonia-Train-Models-/blob/master/Copy_of_ResearchPaperVGG16Net.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from fastai.vision import *
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
from zipfile import ZipFile 
def unZip(file_name):
  with ZipFile(file_name, 'r') as zip: 
      zip.extractall() 
      print('Done!')

# %%
file_name = '/content/drive/chestXRay.zip'

# %%
path="/content/drive/My Drive/"
file_name=path+'chestXRay.zip'

# %%
unZip(file_name)
# Out:
# Done!

# %%
unZip('chest_xray.zip')
# Out:
# Done!

# %%
import glob
import cv2
import numpy as np
# %matplotlib inline
filesPos= sorted(glob.glob('chest_xray/train/NORMAL/*.jpeg'))
filesPos+=sorted(glob.glob('chest_xray/val/NORMAL/*.jpeg'))
filesPos+=sorted(glob.glob('chest_xray/test/NORMAL/*.jpeg'))

# %%
filesNeg=sorted(glob.glob('chest_xray/train/PNEUMONIA/*.jpeg'))
filesNeg+=sorted(glob.glob('chest_xray/val/PNEUMONIA/*.jpeg'))
filesNeg+=sorted(glob.glob('chest_xray/test/PNEUMONIA/*.jpeg'))

# %%
random.shuffle(filesNeg)
len(filesPos),len(filesNeg)
# Out:
# (1583, 4273)

# %%
filesNeg=filesNeg[:2100]

# %%
pos_labels=[[i,0] for i in filesPos]
neg_labels=[[i,1] for i in filesNeg]
ds=pos_labels+neg_labels

# %%
np.random.seed(4200)
import pandas as pd 
df = pd.DataFrame(ds,columns =['path', 'label']) 
def Randomizing(df):
    df2 = df.reindex(np.random.permutation(df.index))
    return df2
df=Randomizing(df)

# %%
from sklearn.model_selection import train_test_split
dfTrain,dfTest=train_test_split(df, shuffle=False,test_size=0.1, random_state=42)

# %%
len(dfTrain),len(dfTest)
# Out:
# (3314, 369)

# %%
dfTrain['label'].hist()
dfTest['label'].hist()

# %%
bs =8
sz=224
tfms = get_transforms(do_flip=True,flip_vert=True,max_lighting=0.4,max_zoom=1.1)
src = (ImageList.from_df(df=dfTrain,path='',cols='path') #get dataset from dataset
        .split_by_rand_pct(0.2) #Splitting the dataset
        .label_from_df(cols='label') #obtain labels from the level column
      )
data= (src.transform(tfms,size=224,padding_mode='zeros') #Data augmentation
        .databunch(bs=bs,num_workers=4) #DataBunch
        .normalize(imagenet_stats) #Normalize     
       )

# %%
data.classes
# Out:
# [0, 1]

# %%
data.show_batch(rows=3, figsize=(10,6), hide_axis=False)

# %%
from sklearn.metrics import roc_auc_score,f1_score
def f1_score_a(y_pred,y_true,tens=True):
#     score=roc_auc_score(y_true,torch.sigmoid(y_pred)[:,1])
    f1a_score=f1_score(y_true, np.round(torch.sigmoid(y_pred)[:,1]), average='macro') 
    if tens:
#         score=tensor(score)
        f1a_score=tensor(f1a_score)
    else:
        f1a_score=f1a_score
    return f1a_score

# %%
import torch 
import torchvision
model = torchvision.models.vgg16(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/checkpoints/vgg16-397923af.pth
# 100%|██████████| 553433881/553433881 [00:04<00:00, 119494506.97it/s]

# %%
# num_ftrs = model.classifier.in_features
model.classifier=nn.Sequential(
    nn.Dropout(0.3),
    nn.Linear(25088, 128),
    nn.Dropout(0.5),
    nn.Linear(128, 2),
    
)

# %%
model=model.cuda()

# %%
from fastai.callbacks import *

learn = Learner(data, model, metrics=[error_rate, accuracy,f1_score_a],callback_fns=[partial(CSVLogger,append=True),BnFreeze, partial(GradientClipping, clip=0.2)])

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot(suggestion=True)
min_grad_lr = learn.recorder.min_grad_lr  if hasattr(learn, 'recorder') else 1e-2
min_grad_lr
# Out:
# Min numerical gradient: 6.31E-07
# Min loss divided by 10: 4.79E-05
# 6.309573444801933e-07

# %%
from fastai.callbacks import *
learn.fit_one_cycle(10,min_grad_lr,callbacks=[SaveModelCallback(learn, every='imrpovement', monitor='f1_score_a')])
# Out:
# /usr/local/lib/python3.6/dist-packages/fastai/callbacks/tracker.py:83: UserWarning: SaveModel every imrpovement is invalid, falling back to "improvement".
#   warn(f'SaveModel every {self.every} is invalid, falling back to "improvement".')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>f1_score_a</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.764390</td>
#       <td>0.731524</td>
#       <td>0.593656</td>
#       <td>0.406344</td>
#       <td>0.358838</td>
#       <td>02:37</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.711794</td>
#       <td>0.660186</td>
#       <td>0.335347</td>
#       <td>0.664653</td>
#       <td>0.496595</td>
#       <td>02:34</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.574996</td>
#       <td>0.543774</td>
#       <td>0.157100</td>
#       <td>0.842900</td>
#       <td>0.732741</td>
#       <td>02:35</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.479514</td>
#       <td>0.407011</td>
#       <td>0.122356</td>
#       <td>0.877644</td>
#       <td>0.857729</td>
#       <td>02:34</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.392184</td>
#       <td>0.303941</td>
#       <td>0.102719</td>
#       <td>0.897281</td>
#       <td>0.892908</td>
#       <td>02:33</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.271012</td>
#       <td>0.261761</td>
#       <td>0.096677</td>
#       <td>0.903323</td>
#       <td>0.906143</td>
#       <td>02:33</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.291360</td>
#       <td>0.256435</td>
#       <td>0.096677</td>
#       <td>0.903323</td>
#       <td>0.907984</td>
#       <td>02:33</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.278972</td>
#       <td>0.249298</td>
#       <td>0.092145</td>
#       <td>0.907855</td>
#       <td>0.909277</td>
#       <td>02:33</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.279354</td>
#       <td>0.261595</td>
#       <td>0.098187</td>
#       <td>0.901813</td>
#       <td>0.902048</td>
#       <td>02:33</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.253026</td>
#       <td>0.260810</td>
#       <td>0.098187</td>
#       <td>0.901813</td>
#       <td>0.902048</td>
#       <td>02:34</td>
#     </tr>
#   </tbody>
# </table>
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Better model found at epoch 0 with f1_score_a value: 0.3588383197784424.
# Better model found at epoch 1 with f1_score_a value: 0.4965950846672058.
# Better model found at epoch 2 with f1_score_a value: 0.732741117477417.
# Better model found at epoch 3 with f1_score_a value: 0.8577293753623962.
# Better model found at epoch 4 with f1_score_a value: 0.8929082751274109.
# Better model found at epoch 5 with f1_score_a value: 0.9061429500579834.
# Better model found at epoch 6 with f1_score_a value: 0.9079844355583191.
# Better model found at epoch 7 with f1_score_a value: 0.9092774987220764.

# %%
learn.load('bestmodel');

# %%
learn.unfreeze()
learn.lr_find()
learn.recorder.plot(suggestion=True)
min_grad_lr = learn.recorder.min_grad_lr  if hasattr(learn, 'recorder') else 1e-2
min_grad_lr
learn.fit_one_cycle(5,min_grad_lr,callbacks=[SaveModelCallback(learn, every='imrpovement', monitor='f1_score_a')])
learn.recorder.plot()
learn.recorder.plot_losses()
learn.recorder.plot_metrics()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 5.25E-05
# Min loss divided by 10: 1.32E-07
# /usr/local/lib/python3.6/dist-packages/fastai/callbacks/tracker.py:83: UserWarning: SaveModel every imrpovement is invalid, falling back to "improvement".
#   warn(f'SaveModel every {self.every} is invalid, falling back to "improvement".')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>f1_score_a</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.327218</td>
#       <td>1.655897</td>
#       <td>0.170695</td>
#       <td>0.829305</td>
#       <td>0.803311</td>
#       <td>02:33</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.459750</td>
#       <td>0.972659</td>
#       <td>0.123867</td>
#       <td>0.876133</td>
#       <td>0.842755</td>
#       <td>02:33</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.277179</td>
#       <td>0.545229</td>
#       <td>0.067976</td>
#       <td>0.932024</td>
#       <td>0.920982</td>
#       <td>02:40</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.272543</td>
#       <td>0.298813</td>
#       <td>0.048338</td>
#       <td>0.951662</td>
#       <td>0.947796</td>
#       <td>02:35</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.177638</td>
#       <td>0.283935</td>
#       <td>0.043807</td>
#       <td>0.956193</td>
#       <td>0.950796</td>
#       <td>02:36</td>
#     </tr>
#   </tbody>
# </table>
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Better model found at epoch 0 with f1_score_a value: 0.8033106923103333.
# Better model found at epoch 1 with f1_score_a value: 0.8427549004554749.
# Better model found at epoch 2 with f1_score_a value: 0.920981764793396.
# Better model found at epoch 3 with f1_score_a value: 0.9477963447570801.
# Better model found at epoch 4 with f1_score_a value: 0.9507957100868225.

# %%
learn.load('bestmodel')
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()
conf=interp.confusion_matrix()
TrueNagitive=conf[0][0]
FalseNegative=conf[0][1]
TruePositive=conf[1][1]
FalsePositive=conf[1][0]
recal=TruePositive/(TruePositive+FalseNegative)
precision=TruePositive/(TruePositive+FalsePositive)
print("Precision of Model =",precision,"Recall of Model ", recal)
f1=2*((precision*recal)/(precision+recal))
print('F1 Score of Model =',f1)

# %%
bs =8
sz=224
tfms = get_transforms(do_flip=True,flip_vert=True,max_lighting=0.4,max_zoom=1.1)
src = (ImageList.from_df(df=dfTest,path='',cols='path') #get dataset from dataset
        .split_by_rand_pct(0.0) #Splitting the dataset
        .label_from_df(cols='label') #obtain labels from the level column
      )
dataTest= (src.transform(tfms,size=224,padding_mode='zeros') #Data augmentation
        .databunch(bs=bs,num_workers=4) #DataBunch
        .normalize(imagenet_stats) #Normalize     
       )

# %%
learn.data.valid_dl = dataTest.train_dl

# %%
learn.validate()
# Out:
# [0.19102198, tensor(0.0299), tensor(0.9701), tensor(0.9659)]

# %%
learn.load('bestmodel')
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()
conf=interp.confusion_matrix()
TrueNagitive=conf[0][0]
FalseNegative=conf[0][1]
TruePositive=conf[1][1]
FalsePositive=conf[1][0]
recal=TruePositive/(TruePositive+FalseNegative)
precision=TruePositive/(TruePositive+FalsePositive)
print("Precision of Model =",precision,"Recall of Model ", recal)
f1=2*((precision*recal)/(precision+recal))
print('F1 Score of Model =',f1)
# Out:
# Precision of Model = 0.9818181818181818 Recall of Model  0.9557522123893806
# F1 Score of Model = 0.968609865470852

# %%
# !ls
# Out:
# chest_xray  chest_xray.zip  drive  history.csv	__MACOSX  models  sample_data

# %%
# !mkdir '/content/drive/My Drive/VGG19Pne1'
# !cp 'models/bestmodel.pth' '/content/drive/My Drive/VGG19Pne1'
# !cp 'history.csv' '/content/drive/My Drive/VGG19Pne1'
