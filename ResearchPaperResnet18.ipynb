# %% [markdown]
# <a href="https://colab.research.google.com/github/m-aliabbas/Pneumonia-Train-Models-/blob/master/ResearchPaperResnet18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from fastai.vision import *
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
from zipfile import ZipFile 
def unZip(file_name):
  with ZipFile(file_name, 'r') as zip: 
      zip.extractall() 
      print('Done!')

# %%
file_name = '/content/drive/chestXRay.zip'

# %%
path="/content/drive/My Drive/"
file_name=path+'chestXRay.zip'

# %%
unZip(file_name)
# Out:
# Done!

# %%
unZip('chest_xray.zip')
# Out:
# Done!

# %%
import glob
import cv2
import numpy as np
# %matplotlib inline
filesPos= sorted(glob.glob('chest_xray/train/NORMAL/*.jpeg'))
filesPos+=sorted(glob.glob('chest_xray/val/NORMAL/*.jpeg'))
filesPos+=sorted(glob.glob('chest_xray/test/NORMAL/*.jpeg'))

# %%
filesNeg=sorted(glob.glob('chest_xray/train/PNEUMONIA/*.jpeg'))
filesNeg+=sorted(glob.glob('chest_xray/val/PNEUMONIA/*.jpeg'))
filesNeg+=sorted(glob.glob('chest_xray/test/PNEUMONIA/*.jpeg'))

# %%
random.shuffle(filesNeg)
len(filesPos),len(filesNeg)
# Out:
# (1583, 4273)

# %%
filesNeg=filesNeg[:2100]

# %%
pos_labels=[[i,0] for i in filesPos]
neg_labels=[[i,1] for i in filesNeg]
ds=pos_labels+neg_labels

# %%
np.random.seed(4200)
import pandas as pd 
df = pd.DataFrame(ds,columns =['path', 'label']) 
def Randomizing(df):
    df2 = df.reindex(np.random.permutation(df.index))
    return df2
df=Randomizing(df)

# %%
from sklearn.model_selection import train_test_split
dfTrain,dfTest=train_test_split(df, shuffle=False,test_size=0.1, random_state=42)

# %%
len(dfTrain),len(dfTest)
# Out:
# (3314, 369)

# %%
dfTrain['label'].hist()
dfTest['label'].hist()

# %%
bs =8
sz=224
tfms = get_transforms(do_flip=True,flip_vert=True,max_lighting=0.4,max_zoom=1.1)
src = (ImageList.from_df(df=dfTrain,path='',cols='path') #get dataset from dataset
        .split_by_rand_pct(0.2) #Splitting the dataset
        .label_from_df(cols='label') #obtain labels from the level column
      )
data= (src.transform(tfms,size=224,padding_mode='zeros') #Data augmentation
        .databunch(bs=bs,num_workers=4) #DataBunch
        .normalize(imagenet_stats) #Normalize     
       )

# %%
data.classes
# Out:
# [0, 1]

# %%
data.show_batch(rows=3, figsize=(10,6), hide_axis=False)

# %%
from sklearn.metrics import roc_auc_score,f1_score
def f1_score_a(y_pred,y_true,tens=True):
#     score=roc_auc_score(y_true,torch.sigmoid(y_pred)[:,1])
    f1a_score=f1_score(y_true, np.round(torch.sigmoid(y_pred)[:,1]), average='macro') 
    if tens:
#         score=tensor(score)
        f1a_score=tensor(f1a_score)
    else:
        f1a_score=f1a_score
    return f1a_score

# %%
import torch 
import torchvision
model = torchvision.models.resnet18(pretrained=True)

# %%
num_ftrs = model.fc.in_features
model.fc=nn.Sequential(
    nn.Dropout(0.3),
    nn.Linear(num_ftrs, 128),
    nn.Dropout(0.5),
    nn.Linear(128, 2),
    
)

# %%
model=model.cuda()

# %%
from fastai.callbacks import *

learn = Learner(data, model, metrics=[error_rate, accuracy,f1_score_a],callback_fns=[partial(CSVLogger,append=True),BnFreeze, partial(GradientClipping, clip=0.2)])

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot(suggestion=True)
min_grad_lr = learn.recorder.min_grad_lr  if hasattr(learn, 'recorder') else 1e-2
# Out:
# Min numerical gradient: 2.29E-06
# Min loss divided by 10: 1.20E-04

# %%
from fastai.callbacks import *
learn.fit_one_cycle(5,min_grad_lr,callbacks=[SaveModelCallback(learn, every='imrpovement', monitor='f1_score_a')])
# Out:
# /usr/local/lib/python3.6/dist-packages/fastai/callbacks/tracker.py:83: UserWarning: SaveModel every imrpovement is invalid, falling back to "improvement".
#   warn(f'SaveModel every {self.every} is invalid, falling back to "improvement".')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>f1_score_a</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.748261</td>
#       <td>0.661322</td>
#       <td>0.385196</td>
#       <td>0.614804</td>
#       <td>0.520009</td>
#       <td>02:46</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.566924</td>
#       <td>0.448277</td>
#       <td>0.104230</td>
#       <td>0.895770</td>
#       <td>0.827153</td>
#       <td>02:43</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.439427</td>
#       <td>0.344672</td>
#       <td>0.099698</td>
#       <td>0.900302</td>
#       <td>0.857327</td>
#       <td>02:43</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.411732</td>
#       <td>0.303898</td>
#       <td>0.101208</td>
#       <td>0.898792</td>
#       <td>0.882113</td>
#       <td>02:44</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.386391</td>
#       <td>0.299985</td>
#       <td>0.095166</td>
#       <td>0.904834</td>
#       <td>0.876408</td>
#       <td>02:41</td>
#     </tr>
#   </tbody>
# </table>
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Better model found at epoch 0 with f1_score_a value: 0.5200088024139404.
# Better model found at epoch 1 with f1_score_a value: 0.8271526098251343.
# Better model found at epoch 2 with f1_score_a value: 0.8573267459869385.
# Better model found at epoch 3 with f1_score_a value: 0.8821132779121399.

# %%
learn.recorder.plot()
learn.recorder.plot_losses()
learn.recorder.plot_metrics()

# %%
learn.lr_find()
learn.recorder.plot(suggestion=True)
min_grad_lr = learn.recorder.min_grad_lr  if hasattr(learn, 'recorder') else 1e-2
from fastai.callbacks import *
learn.fit_one_cycle(5,min_grad_lr,callbacks=[SaveModelCallback(learn, every='imrpovement', monitor='f1_score_a')])
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 6.92E-06
# Min loss divided by 10: 1.58E-07
# /usr/local/lib/python3.6/dist-packages/fastai/callbacks/tracker.py:83: UserWarning: SaveModel every imrpovement is invalid, falling back to "improvement".
#   warn(f'SaveModel every {self.every} is invalid, falling back to "improvement".')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>f1_score_a</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.375867</td>
#       <td>0.235657</td>
#       <td>0.084592</td>
#       <td>0.915408</td>
#       <td>0.905858</td>
#       <td>02:45</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.321333</td>
#       <td>0.201764</td>
#       <td>0.075529</td>
#       <td>0.924471</td>
#       <td>0.908363</td>
#       <td>02:44</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.278870</td>
#       <td>0.176543</td>
#       <td>0.070997</td>
#       <td>0.929003</td>
#       <td>0.921565</td>
#       <td>02:44</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.243445</td>
#       <td>0.221005</td>
#       <td>0.069486</td>
#       <td>0.930514</td>
#       <td>0.915900</td>
#       <td>03:39</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.273614</td>
#       <td>0.199183</td>
#       <td>0.067976</td>
#       <td>0.932024</td>
#       <td>0.923608</td>
#       <td>03:56</td>
#     </tr>
#   </tbody>
# </table>
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Better model found at epoch 0 with f1_score_a value: 0.9058579802513123.
# Better model found at epoch 1 with f1_score_a value: 0.9083629846572876.
# Better model found at epoch 2 with f1_score_a value: 0.9215654134750366.
# Better model found at epoch 4 with f1_score_a value: 0.9236082434654236.

# %%
learn.recorder.plot()
learn.recorder.plot_losses()
learn.recorder.plot_metrics()

# %%
learn.load('bestmodel')

# %%
learn.load('bestmodel')
learn.unfreeze()
learn.lr_find()
learn.recorder.plot(suggestion=True)
min_grad_lr = learn.recorder.min_grad_lr  if hasattr(learn, 'recorder') else 1e-2
min_grad_lr
learn.fit_one_cycle(5,min_grad_lr,callbacks=[SaveModelCallback(learn, every='imrpovement', monitor='f1_score_a')])
learn.recorder.plot()
learn.recorder.plot_losses()
learn.recorder.plot_metrics()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 9.12E-07
# Min loss divided by 10: 3.31E-05
# /usr/local/lib/python3.6/dist-packages/fastai/callbacks/tracker.py:83: UserWarning: SaveModel every imrpovement is invalid, falling back to "improvement".
#   warn(f'SaveModel every {self.every} is invalid, falling back to "improvement".')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>f1_score_a</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.235781</td>
#       <td>0.172659</td>
#       <td>0.063444</td>
#       <td>0.936556</td>
#       <td>0.930838</td>
#       <td>03:31</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.301512</td>
#       <td>0.220923</td>
#       <td>0.067976</td>
#       <td>0.932024</td>
#       <td>0.916665</td>
#       <td>03:26</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.292472</td>
#       <td>0.194782</td>
#       <td>0.063444</td>
#       <td>0.936556</td>
#       <td>0.928061</td>
#       <td>02:41</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.295562</td>
#       <td>0.212813</td>
#       <td>0.064955</td>
#       <td>0.935045</td>
#       <td>0.922213</td>
#       <td>02:41</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.272236</td>
#       <td>0.216468</td>
#       <td>0.066465</td>
#       <td>0.933535</td>
#       <td>0.922261</td>
#       <td>02:42</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with f1_score_a value: 0.9308379292488098.
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
learn.recorder.plot()
learn.load('bestmodel')
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()

# %%
learn.recorder.plot_losses()
learn.recorder.plot_metrics()

# %%
learn.load('bestmodel')
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()
conf=interp.confusion_matrix()
TrueNagitive=conf[0][0]
FalseNegative=conf[0][1]
TruePositive=conf[1][1]
FalsePositive=conf[1][0]
recal=TruePositive/(TruePositive+FalseNegative)
precision=TruePositive/(TruePositive+FalsePositive)
print("Precision of Model =",precision,"Recall of Model ", recal)
f1=2*((precision*recal)/(precision+recal))
print('F1 Score of Model =',f1)
# Out:
# Precision of Model = 0.9153439153439153 Recall of Model  0.9719101123595506
# F1 Score of Model = 0.9427792915531336

# %%
bs =8
sz=224
tfms = get_transforms(do_flip=True,flip_vert=True,max_lighting=0.4,max_zoom=1.1)
src = (ImageList.from_df(df=dfTest,path='',cols='path') #get dataset from dataset
        .split_by_rand_pct(0.0) #Splitting the dataset
        .label_from_df(cols='label') #obtain labels from the level column
      )
data= (src.transform(tfms,size=224,padding_mode='zeros') #Data augmentation
        .databunch(bs=bs,num_workers=4) #DataBunch
        .normalize(imagenet_stats) #Normalize     
       )

# %%
learn.data.valid_dl = data.train_dl

# %%
learn.validate()
# Out:
# [0.17887546, tensor(0.0571), tensor(0.9429), tensor(0.9162)]

# %%
log_preds, test_labels = learn.TTA()
log_preds
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-ed748cb9f1d8> in <module>()
#       1 log_preds, test_labels = learn.TTA()
# ----> 2 np.mean(test_labels)
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py in mean(a, axis, dtype, out, keepdims)
#    3113             pass
#    3114         else:
# -> 3115             return mean(axis=axis, dtype=dtype, out=out, **kwargs)
#    3116
#    3117     return _methods._mean(a, axis=axis, dtype=dtype,
#
# TypeError: mean() missing 3 required positional argument: "dim", "keepdim", "dtype"

# %%
learn.load('bestmodel')
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()
conf=interp.confusion_matrix()
TrueNagitive=conf[0][0]
FalseNegative=conf[0][1]
TruePositive=conf[1][1]
FalsePositive=conf[1][0]
recal=TruePositive/(TruePositive+FalseNegative)
precision=TruePositive/(TruePositive+FalsePositive)
print("Precision of Model =",precision,"Recall of Model ", recal)
f1=2*((precision*recal)/(precision+recal))
print('F1 Score of Model =',f1)
# Out:
# Precision of Model = 0.9727272727272728 Recall of Model  0.9224137931034483
# F1 Score of Model = 0.9469026548672567

# %%
# !ls
# Out:
# chest_xray  chest_xray.zip  drive  history.csv	__MACOSX  models  sample_data

# %%
# !mkdir '/content/drive/My Drive/Resnet18Pne'
# !cp 'models/bestmodel.pth' '/content/drive/My Drive/Resnet18Pne'
# !cp 'history.csv' '/content/drive/My Drive/Resnet18Pne'
# Out:
# mkdir: cannot create directory ‘/content/drive/My Drive/Resnet18Pne’: File exists
