# %% [markdown]
# <a href="https://colab.research.google.com/github/m-aliabbas/Pneumonia-Train-Models-/blob/master/ResearchPaperDenseNet121.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from fastai.vision import *
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
from zipfile import ZipFile 
def unZip(file_name):
  with ZipFile(file_name, 'r') as zip: 
      zip.extractall() 
      print('Done!')

# %%
file_name = '/content/drive/chestXRay.zip'

# %%
path="/content/drive/My Drive/"
file_name=path+'chestXRay.zip'

# %%
unZip(file_name)
# Out:
# Done!

# %%
unZip('chest_xray.zip')
# Out:
# Done!

# %%
import glob
import cv2
import numpy as np
# %matplotlib inline
filesPos= sorted(glob.glob('chest_xray/train/NORMAL/*.jpeg'))
filesPos+=sorted(glob.glob('chest_xray/val/NORMAL/*.jpeg'))
filesPos+=sorted(glob.glob('chest_xray/test/NORMAL/*.jpeg'))

# %%
filesNeg=sorted(glob.glob('chest_xray/train/PNEUMONIA/*.jpeg'))
filesNeg+=sorted(glob.glob('chest_xray/val/PNEUMONIA/*.jpeg'))
filesNeg+=sorted(glob.glob('chest_xray/test/PNEUMONIA/*.jpeg'))

# %%
random.shuffle(filesNeg)
len(filesPos),len(filesNeg)
# Out:
# (1583, 4273)

# %%
filesNeg=filesNeg[:2100]

# %%
pos_labels=[[i,0] for i in filesPos]
neg_labels=[[i,1] for i in filesNeg]
ds=pos_labels+neg_labels

# %%
np.random.seed(4200)
import pandas as pd 
df = pd.DataFrame(ds,columns =['path', 'label']) 
def Randomizing(df):
    df2 = df.reindex(np.random.permutation(df.index))
    return df2
df=Randomizing(df)

# %%
from sklearn.model_selection import train_test_split
dfTrain,dfTest=train_test_split(df, shuffle=False,test_size=0.1, random_state=42)

# %%
len(dfTrain),len(dfTest)
# Out:
# (3314, 369)

# %%
dfTrain['label'].hist()
dfTest['label'].hist()

# %%
bs =8
sz=224
tfms = get_transforms(do_flip=True,flip_vert=True,max_lighting=0.4,max_zoom=1.1)
src = (ImageList.from_df(df=dfTrain,path='',cols='path') #get dataset from dataset
        .split_by_rand_pct(0.2) #Splitting the dataset
        .label_from_df(cols='label') #obtain labels from the level column
      )
data= (src.transform(tfms,size=224,padding_mode='zeros') #Data augmentation
        .databunch(bs=bs,num_workers=4) #DataBunch
        .normalize(imagenet_stats) #Normalize     
       )

# %%
data.classes
# Out:
# [0, 1]

# %%
data.show_batch(rows=3, figsize=(10,6), hide_axis=False)

# %%
from sklearn.metrics import roc_auc_score,f1_score
def f1_score_a(y_pred,y_true,tens=True):
#     score=roc_auc_score(y_true,torch.sigmoid(y_pred)[:,1])
    f1a_score=f1_score(y_true, np.round(torch.sigmoid(y_pred)[:,1]), average='macro') 
    if tens:
#         score=tensor(score)
        f1a_score=tensor(f1a_score)
    else:
        f1a_score=f1a_score
    return f1a_score

# %%
import torch 
import torchvision
model = torchvision.models.densenet121(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to /root/.cache/torch/checkpoints/densenet121-a639ec97.pth
# 100%|██████████| 32342954/32342954 [00:01<00:00, 18674525.81it/s]

# %%
num_ftrs = model.classifier.in_features
model.classifier=nn.Sequential(
    nn.Dropout(0.3),
    nn.Linear(num_ftrs, 128),
    nn.Dropout(0.5),
    nn.Linear(128, 2),
    
)

# %%
model=model.cuda()

# %%
from fastai.callbacks import *

learn = Learner(data, model, metrics=[error_rate, accuracy,f1_score_a],callback_fns=[partial(CSVLogger,append=True),BnFreeze, partial(GradientClipping, clip=0.2)])

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot(suggestion=True)
min_grad_lr = learn.recorder.min_grad_lr  if hasattr(learn, 'recorder') else 1e-2
# Out:
# Min numerical gradient: 1.32E-06
# Min loss divided by 10: 6.31E-04

# %%
from fastai.callbacks import *
learn.fit_one_cycle(7,min_grad_lr,callbacks=[SaveModelCallback(learn, every='imrpovement', monitor='f1_score_a')])
# Out:
# /usr/local/lib/python3.6/dist-packages/fastai/callbacks/tracker.py:83: UserWarning: SaveModel every imrpovement is invalid, falling back to "improvement".
#   warn(f'SaveModel every {self.every} is invalid, falling back to "improvement".')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>f1_score_a</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.716804</td>
#       <td>0.698066</td>
#       <td>0.456193</td>
#       <td>0.543807</td>
#       <td>0.352303</td>
#       <td>02:50</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.662296</td>
#       <td>0.644714</td>
#       <td>0.356495</td>
#       <td>0.643505</td>
#       <td>0.354354</td>
#       <td>02:51</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.638564</td>
#       <td>0.581902</td>
#       <td>0.157100</td>
#       <td>0.842900</td>
#       <td>0.376208</td>
#       <td>02:50</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.554689</td>
#       <td>0.549847</td>
#       <td>0.164653</td>
#       <td>0.835347</td>
#       <td>0.615266</td>
#       <td>02:50</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.525763</td>
#       <td>0.501932</td>
#       <td>0.119335</td>
#       <td>0.880665</td>
#       <td>0.675566</td>
#       <td>02:50</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.502995</td>
#       <td>0.478706</td>
#       <td>0.114804</td>
#       <td>0.885196</td>
#       <td>0.698269</td>
#       <td>02:51</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.493828</td>
#       <td>0.473828</td>
#       <td>0.108761</td>
#       <td>0.891239</td>
#       <td>0.745936</td>
#       <td>02:50</td>
#     </tr>
#   </tbody>
# </table>
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Better model found at epoch 0 with f1_score_a value: 0.35230332612991333.
# Better model found at epoch 1 with f1_score_a value: 0.35435405373573303.
# Better model found at epoch 2 with f1_score_a value: 0.3762076199054718.
# Better model found at epoch 3 with f1_score_a value: 0.6152658462524414.
# Better model found at epoch 4 with f1_score_a value: 0.6755657196044922.
# Better model found at epoch 5 with f1_score_a value: 0.698268711566925.
# Better model found at epoch 6 with f1_score_a value: 0.7459364533424377.

# %%
learn.fit_one_cycle(7,min_grad_lr,callbacks=[SaveModelCallback(learn, every='imrpovement', monitor='f1_score_a')])
learn.recorder.plot()
learn.recorder.plot_losses()
learn.recorder.plot_metrics()
# Out:
# /usr/local/lib/python3.6/dist-packages/fastai/callbacks/tracker.py:83: UserWarning: SaveModel every imrpovement is invalid, falling back to "improvement".
#   warn(f'SaveModel every {self.every} is invalid, falling back to "improvement".')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>f1_score_a</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.486772</td>
#       <td>0.457108</td>
#       <td>0.098187</td>
#       <td>0.901813</td>
#       <td>0.759904</td>
#       <td>02:50</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.458386</td>
#       <td>0.411575</td>
#       <td>0.102719</td>
#       <td>0.897281</td>
#       <td>0.867082</td>
#       <td>02:50</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.433205</td>
#       <td>0.365187</td>
#       <td>0.101208</td>
#       <td>0.898792</td>
#       <td>0.901888</td>
#       <td>02:50</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.376272</td>
#       <td>0.301775</td>
#       <td>0.078550</td>
#       <td>0.921450</td>
#       <td>0.905383</td>
#       <td>02:51</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.379913</td>
#       <td>0.273207</td>
#       <td>0.074018</td>
#       <td>0.925982</td>
#       <td>0.903414</td>
#       <td>02:50</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.371538</td>
#       <td>0.314143</td>
#       <td>0.110272</td>
#       <td>0.889728</td>
#       <td>0.897882</td>
#       <td>02:51</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.331872</td>
#       <td>0.303401</td>
#       <td>0.101208</td>
#       <td>0.898792</td>
#       <td>0.898949</td>
#       <td>02:51</td>
#     </tr>
#   </tbody>
# </table>
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Better model found at epoch 0 with f1_score_a value: 0.7599040865898132.
# Better model found at epoch 1 with f1_score_a value: 0.8670816421508789.
# Better model found at epoch 2 with f1_score_a value: 0.901888370513916.
# Better model found at epoch 3 with f1_score_a value: 0.9053834080696106.

# %%
learn.load('bestmodel');

# %%
learn.unfreeze()
learn.lr_find()
learn.recorder.plot(suggestion=True)
min_grad_lr = learn.recorder.min_grad_lr  if hasattr(learn, 'recorder') else 1e-2
min_grad_lr
learn.fit_one_cycle(5,min_grad_lr,callbacks=[SaveModelCallback(learn, every='imrpovement', monitor='f1_score_a')])
learn.recorder.plot()
learn.recorder.plot_losses()
learn.recorder.plot_metrics()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 6.31E-07
# Min loss divided by 10: 7.59E-08
# /usr/local/lib/python3.6/dist-packages/fastai/callbacks/tracker.py:83: UserWarning: SaveModel every imrpovement is invalid, falling back to "improvement".
#   warn(f'SaveModel every {self.every} is invalid, falling back to "improvement".')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>f1_score_a</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.383217</td>
#       <td>0.305884</td>
#       <td>0.092145</td>
#       <td>0.907855</td>
#       <td>0.903716</td>
#       <td>02:51</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.397391</td>
#       <td>0.279645</td>
#       <td>0.078550</td>
#       <td>0.921450</td>
#       <td>0.910646</td>
#       <td>02:51</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.353872</td>
#       <td>0.272453</td>
#       <td>0.089124</td>
#       <td>0.910876</td>
#       <td>0.906515</td>
#       <td>02:51</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.348197</td>
#       <td>0.290399</td>
#       <td>0.101208</td>
#       <td>0.898792</td>
#       <td>0.892866</td>
#       <td>02:50</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.351760</td>
#       <td>0.323332</td>
#       <td>0.119335</td>
#       <td>0.880665</td>
#       <td>0.886102</td>
#       <td>02:51</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with f1_score_a value: 0.9037158489227295.
# Better model found at epoch 1 with f1_score_a value: 0.9106455445289612.
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
learn.load('bestmodel')
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()
conf=interp.confusion_matrix()
TrueNagitive=conf[0][0]
FalseNegative=conf[0][1]
TruePositive=conf[1][1]
FalsePositive=conf[1][0]
recal=TruePositive/(TruePositive+FalseNegative)
precision=TruePositive/(TruePositive+FalsePositive)
print("Precision of Model =",precision,"Recall of Model ", recal)
f1=2*((precision*recal)/(precision+recal))
print('F1 Score of Model =',f1)
# Out:
# Precision of Model = 0.8888888888888888 Recall of Model  0.9710982658959537
# F1 Score of Model = 0.9281767955801103

# %%
bs =8
sz=224
tfms = get_transforms(do_flip=True,flip_vert=True,max_lighting=0.4,max_zoom=1.1)
src = (ImageList.from_df(df=dfTest,path='',cols='path') #get dataset from dataset
        .split_by_rand_pct(0.0) #Splitting the dataset
        .label_from_df(cols='label') #obtain labels from the level column
      )
dataTest= (src.transform(tfms,size=224,padding_mode='zeros') #Data augmentation
        .databunch(bs=bs,num_workers=4) #DataBunch
        .normalize(imagenet_stats) #Normalize     
       )

# %%
learn.data.valid_dl = dataTest.train_dl

# %%
learn.validate()
# Out:
# [0.29970437, tensor(0.0951), tensor(0.9049), tensor(0.8636)]

# %%
learn.load('bestmodel')
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()
conf=interp.confusion_matrix()
TrueNagitive=conf[0][0]
FalseNegative=conf[0][1]
TruePositive=conf[1][1]
FalsePositive=conf[1][0]
recal=TruePositive/(TruePositive+FalseNegative)
precision=TruePositive/(TruePositive+FalsePositive)
print("Precision of Model =",precision,"Recall of Model ", recal)
f1=2*((precision*recal)/(precision+recal))
print('F1 Score of Model =',f1)
# Out:
# Precision of Model = 0.95 Recall of Model  0.8931623931623932
# F1 Score of Model = 0.9207048458149779

# %%
# !ls
# Out:
# chest_xray  chest_xray.zip  drive  history.csv	__MACOSX  models  sample_data

# %%
# !mkdir '/content/drive/My Drive/DenseNet121Pne1'
# !cp 'models/bestmodel.pth' '/content/drive/My Drive/DenseNet121Pne1'
# !cp 'history.csv' '/content/drive/My Drive/DenseNet121Pne1'
